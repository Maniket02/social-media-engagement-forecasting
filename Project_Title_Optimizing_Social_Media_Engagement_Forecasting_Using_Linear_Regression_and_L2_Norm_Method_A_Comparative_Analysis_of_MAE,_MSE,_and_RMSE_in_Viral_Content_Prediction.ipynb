# %%
import numpy as np   # Numerical Library # Array
import pandas as pd   # Data Analysys  Tabular Analysys
import matplotlib.pyplot as plt   # Data Visua
import seaborn as sn  # Data Visual

# %% [markdown]
# # **Read Data**

# %%
df = pd.read_csv ('Social_Media_vs_Viral_Content.csv')  # This is To Read CSV file

# %%
df
# Out:
#     Social Media Shares  Viral Score
# 0                   100        13.99
# 1                   109        13.45
# 2                   118        15.75
# 3                   127        18.23
# 4                   136        15.44
# ..                  ...          ...
# 95                  963        79.16
# 96                  972        83.41
# 97                  981        84.07
# 98                  990        84.28
# 99                 1000        84.53
#
# [100 rows x 2 columns]

# %% [markdown]
# # **EDA - Summary of Data, Data Visualization**

# %% [markdown]
# # **Explore Data in Depth**

# %%
df.shape  # Column and Row
# Out:
# (100, 2)

# %%
df.columns  # Column Name
# Out:
# Index(['Social Media Shares', 'Viral Score'], dtype='object')

# %%
df.dtypes  # Data Type of Each Column
# Out:
# Social Media Shares      int64
# Viral Score            float64
# dtype: object

# %%
df.count()   # There is no Data Missing in Data set
# Out:
# Social Media Shares    100
# Viral Score            100
# dtype: int64

# %%
df.isnull().sum()  # There is no Data Missing in Data set
# Out:
# Social Media Shares    0
# Viral Score            0
# dtype: int64

# %%
df.head()  # First 5 Reading
# Out:
#    Social Media Shares  Viral Score
# 0                  100        13.99
# 1                  109        13.45
# 2                  118        15.75
# 3                  127        18.23
# 4                  136        15.44

# %%
df.head(10)
# Out:
#    Social Media Shares  Viral Score
# 0                  100        13.99
# 1                  109        13.45
# 2                  118        15.75
# 3                  127        18.23
# 4                  136        15.44
# 5                  145        16.17
# 6                  154        20.52
# 7                  163        19.63
# 8                  172        17.88
# 9                  181        20.63

# %%
df.columns
# Out:
# Index(['Social Media Shares', 'Viral Score'], dtype='object')

# %%
df.tail()
# Out:
#     Social Media Shares  Viral Score
# 95                  963        79.16
# 96                  972        83.41
# 97                  981        84.07
# 98                  990        84.28
# 99                 1000        84.53

# %%
df.tail(10)
# Out:
#     Social Media Shares  Viral Score
# 90                  918        78.65
# 91                  927        81.12
# 92                  936        78.50
# 93                  945        79.98
# 94                  954        80.58
# 95                  963        79.16
# 96                  972        83.41
# 97                  981        84.07
# 98                  990        84.28
# 99                 1000        84.53

# %%
df.sample()
# Out:
#     Social Media Shares  Viral Score
# 10                  190        19.35

# %%
df.sample(5)
# Out:
#     Social Media Shares  Viral Score
# 72                  754        65.29
# 76                  790        68.45
# 93                  945        79.98
# 43                  490        43.67
# 10                  190        19.35

# %%
df[50:100]
# Out:
#     Social Media Shares  Viral Score
# 50                  554        50.01
# 51                  563        49.32
# 52                  572        49.46
# 53                  581        52.77
# 54                  590        54.33
# 55                  600        54.86
# 56                  609        52.05
# 57                  618        53.84
# 58                  627        55.84
# 59                  636        57.86
# 60                  645        55.68
# 61                  654        56.99
# 62                  663        55.88
# 63                  672        56.43
# 64                  681        61.17
# 65                  690        62.99
# 66                  700        60.86
# 67                  709        63.73
# 68                  718        63.18
# 69                  727        61.89
# 70                  736        64.63
# 71                  745        67.71
# 72                  754        65.29
# 73                  763        69.22
# 74                  772        61.58
# 75                  781        69.19
# 76                  790        68.45
# 77                  800        68.40
# 78                  809        69.91
# 79                  818        66.48
# 80                  827        70.74
# 81                  836        72.62
# 82                  845        75.59
# 83                  854        72.33
# 84                  863        72.47
# 85                  872        73.81
# 86                  881        77.38
# 87                  890        76.93
# 88                  900        75.94
# 89                  909        78.75
# 90                  918        78.65
# 91                  927        81.12
# 92                  936        78.50
# 93                  945        79.98
# 94                  954        80.58
# 95                  963        79.16
# 96                  972        83.41
# 97                  981        84.07
# 98                  990        84.28
# 99                 1000        84.53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Social Media Shares  100 non-null    int64
#  1   Viral Score          100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#        Social Media Shares  Viral Score
# count           100.000000   100.000000
# mean            549.550000    48.792000
# std             263.717494    21.257429
# min             100.000000    13.450000
# 25%             324.750000    30.262500
# 50%             549.500000    49.310000
# 75%             774.250000    67.882500
# max            1000.000000    84.530000

# %%
df.describe().T
# Out:
#                      count     mean         std     min       25%     50%  \
# Social Media Shares  100.0  549.550  263.717494  100.00  324.7500  549.50
# Viral Score          100.0   48.792   21.257429   13.45   30.2625   49.31
#
#                           75%      max
# Social Media Shares  774.2500  1000.00
# Viral Score           67.8825    84.53

# %% [markdown]
# # **Visualization of Data**

# %%
df.hist(figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'Social Media Shares'}>,
#         <Axes: title={'center': 'Viral Score'}>]], dtype=object)

# %%
df.columns
# Out:
# Index(['Social Media Shares', 'Viral Score'], dtype='object')

# %%
sn.scatterplot(x='Social Media Shares', y='Viral Score',data=df)
plt.show()

# %%
df
# Out:
#     Social Media Shares  Viral Score
# 0                   100        13.99
# 1                   109        13.45
# 2                   118        15.75
# 3                   127        18.23
# 4                   136        15.44
# ..                  ...          ...
# 95                  963        79.16
# 96                  972        83.41
# 97                  981        84.07
# 98                  990        84.28
# 99                 1000        84.53
#
# [100 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Social Media Shares', 'Viral Score'], dtype='object')

# %%
x = df['Social Media Shares']
y = df['Viral Score'] # dependent variable

# %%
x
# Out:
# 0      100
# 1      109
# 2      118
# 3      127
# 4      136
#       ...
# 95     963
# 96     972
# 97     981
# 98     990
# 99    1000
# Name: Social Media Shares, Length: 100, dtype: int64

# %%
y
# Out:
# 0     13.99
# 1     13.45
# 2     15.75
# 3     18.23
# 4     15.44
#       ...
# 95    79.16
# 96    83.41
# 97    84.07
# 98    84.28
# 99    84.53
# Name: Viral Score, Length: 100, dtype: float64

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(x,y,test_size=0.3)
X_train.info()
X_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 70 entries, 81 to 72
# Series name: Social Media Shares
# Non-Null Count  Dtype
# --------------  -----
# 70 non-null     int64
# dtypes: int64(1)
# memory usage: 1.1 KB
# <class 'pandas.core.series.Series'>
# Index: 30 entries, 48 to 24
# Series name: Social Media Shares
# Non-Null Count  Dtype
# --------------  -----
# 30 non-null     int64
# dtypes: int64(1)
# memory usage: 480.0 bytes

# %% [markdown]
# # **Select Model ML**

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %% [markdown]
# # **Trainig**

# %%
# Reshape X_train and X_test to be 2D DataFrames
X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

# %%
lm.fit(X_train, y_train )  # Training
# Out:
# LinearRegression()

# %% [markdown]
# # **Testing**

# %%
predictions = lm.predict(X_test)  # Testing

# %% [markdown]
# # **Model Evaluation**

# %% [markdown]
# # **Error Calcuation**

# %% [markdown]
# ![Slide1.JPG](data:image/jpeg;base64,...)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Combine training and testing data
X_full = np.concatenate([X_train, X_test])
y_full = np.concatenate([y_train, y_test])

# %%
# Predict on the full dataset
predictions_full = lm.predict(X_full)

# %%
# Evaluation metrics
mae = mean_absolute_error(y_full, predictions_full)
mse = mean_squared_error(y_full, predictions_full)
rmse = np.sqrt(mse)

# %%
print(f'MAE: {mae:.2f}')
print(f'MSE: {mse:.2f}')
print(f'RMSE: {rmse:.2f}')
# Out:
# MAE: 1.43
# MSE: 3.27
# RMSE: 1.81

# %%
import numpy as np   # Evaluation
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, predictions)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, predictions)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, predictions))))
# Out:
# MAE: 1.3759641885887697
# MSE: 2.9603275555359847
# RMSE: 1.7205602446691557
